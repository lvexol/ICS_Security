# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from torch.utils.data import DataLoader, TensorDataset

# %%
# ---------- CONFIGURATION ----------
preprocessed_folder = "/home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data"  # Same folder where preprocessed batches were saved
output_folder = "/home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results"
os.makedirs(output_folder, exist_ok=True)

# %%
batch_files = sorted([os.path.join(preprocessed_folder, f) for f in os.listdir(preprocessed_folder) if f.startswith("preprocessed_batch_")])

# %%
# ---------- Autoencoder Model ----------
class Autoencoder(nn.Module):
    def __init__(self, input_dim):
        super(Autoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 32),
            nn.ReLU(),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 8),
            nn.ReLU()
        )
        self.decoder = nn.Sequential(
            nn.Linear(8, 16),
            nn.ReLU(),
            nn.Linear(16, 32),
            nn.ReLU(),
            nn.Linear(32, input_dim),
            nn.Sigmoid()
        )

    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
# ---------- Training Function ----------
def train_autoencoder(model, dataloader, epochs=1, device="cpu"):
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    model.train()
    for epoch in range(epochs):
        total_loss = 0
        for data in dataloader:
            inputs = data[0].to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, inputs)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        print(f"Epoch [{epoch+1}/{epochs}] Loss: {total_loss / len(dataloader):.6f}")

# %%
# ---------- Compute Reconstruction Error ----------
def compute_reconstruction_error(model, loader, device):
    model.eval()
    errors = []
    with torch.no_grad():
        for batch in loader:
            inputs = batch[0].to(device)
            outputs = model(inputs)
            error = torch.mean((inputs - outputs) ** 2, dim=1).cpu().numpy()
            errors.extend(error)
    return np.array(errors)

# %%
# ---------- Train Model Batchwise with Train Accuracy ----------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
autoencoder = None  # Model will be initialized on first batch
threshold = None  # Stores anomaly detection threshold after first batch

# %%
for batch_num, batch_file in enumerate(batch_files, 1):
    print(f"\n🔹 Processing Batch {batch_num}: {batch_file}")

    # Load Data
    df = pd.read_csv(batch_file)

    # Scale Data
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(df.drop(columns=['Tag'], errors='ignore'))  # Drop label if exists

    # Convert to PyTorch Tensors
    X_tensor = torch.tensor(X_scaled, dtype=torch.float32)
    dataloader = DataLoader(TensorDataset(X_tensor), batch_size=256, shuffle=True)

    # Initialize Model on First Batch
    if autoencoder is None:
        input_dim = X_tensor.shape[1]
        autoencoder = Autoencoder(input_dim).to(device)

    # Train Autoencoder on This Batch
    train_autoencoder(autoencoder, dataloader, epochs=1, device=device)

    # Save Model After Each Batch
    model_path = os.path.join(output_folder, f"autoencoder_progressive.pth")
    torch.save(autoencoder.state_dict(), model_path)
    print(f"✅ Model saved: {model_path}")

    model_path = os.path.join(output_folder, f"autoencoder_progressive.h5")
    torch.save(autoencoder.state_dict(), model_path)
    print(f"✅ Model saved: {model_path}")

    # Compute Reconstruction Error for Train Data
    reconstruction_errors = compute_reconstruction_error(autoencoder, dataloader, device)

    # Set Threshold Based on First Batch (95th Percentile)
    if threshold is None:
        threshold = np.percentile(reconstruction_errors, 95)
        print(f"🔹 Set Anomaly Threshold: {threshold:.6f}")

    # Detect Anomalies in Training Data
    train_predictions = (reconstruction_errors > threshold).astype(int)  # 1 = anomaly, 0 = normal

    # Compute Train Accuracy
    train_accuracy = accuracy_score(np.zeros_like(train_predictions), train_predictions)  # Assuming all training data is normal
    print(f"✅ Train Accuracy for Batch {batch_num}: {train_accuracy:.4f}")

    # Save Train Accuracy
    with open(os.path.join(output_folder, "train_accuracy_log.txt"), "a") as log_file:
        log_file.write(f"Batch {batch_num}: Train Accuracy = {train_accuracy:.4f}\n")

    # Save Anomaly Results
    df['reconstruction_error'] = reconstruction_errors
    df['anomaly'] = train_predictions

    result_file = os.path.join(output_folder, f"anomaly_results_batch_{batch_num}.csv")
    df.to_csv(result_file, index=False)
    print(f"✅ Anomalies saved to {result_file}")
    print(f"🔔 Detected {df['anomaly'].sum()} anomalies out of {len(df)} rows in Batch {batch_num}")

print("\n✅ Batchwise Anomaly Detection Completed.")
# Out:
# 🔹 Processing Batch 1: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/preprocessed_batch_1.csv
# Epoch [1/1] Loss: 0.832700
# ✅ Model saved: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/autoencoder_progressive.pth
# ✅ Model saved: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/autoencoder_progressive.h5
# 🔹 Set Anomaly Threshold: 0.662226
# ✅ Train Accuracy for Batch 1: 0.9500
# ✅ Anomalies saved to /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/anomaly_results_batch_1.csv
# 🔔 Detected 346463 anomalies out of 6929245 rows in Batch 1
#
# 🔹 Processing Batch 2: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/preprocessed_batch_10.csv
# Epoch [1/1] Loss: 0.836621
# ✅ Model saved: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/autoencoder_progressive.pth
# ✅ Model saved: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/autoencoder_progressive.h5
# ✅ Train Accuracy for Batch 2: 0.8993
# ✅ Anomalies saved to /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/anomaly_results_batch_2.csv
# 🔔 Detected 699017 anomalies out of 6940325 rows in Batch 2
#
# 🔹 Processing Batch 3: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/preprocessed_batch_11.csv
# Epoch [1/1] Loss: 0.827414
# ✅ Model saved: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/autoencoder_progressive.pth
# ✅ Model saved: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/autoencoder_progressive.h5
# ✅ Train Accuracy for Batch 3: 0.9484
# ✅ Anomalies saved to /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/anomaly_results_batch_3.csv
# 🔔 Detected 357690 anomalies out of 6929237 rows in Batch 3
#
# 🔹 Processing Batch 4: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/preprocessed_batch_12.csv
# Epoch [1/1] Loss: 0.826275
# ✅ Model saved: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/autoencoder_progressive.pth
# ✅ Model saved: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/autoencoder_progressive.h5
# ✅ Train Accuracy for Batch 4: 0.9128
# ✅ Anomalies saved to /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/anomaly_results_batch_4.csv
# 🔔 Detected 605486 anomalies out of 6940231 rows in Batch 4
#
# 🔹 Processing Batch 5: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/preprocessed_batch_13.csv
# Epoch [1/1] Loss: 0.825515
# ✅ Model saved: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/autoencoder_progressive.pth
# ✅ Model saved: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/autoencoder_progressive.h5
# ✅ Train Accuracy for Batch 5: 0.9195
# ✅ Anomalies saved to /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/anomaly_results_batch_5.csv
# 🔔 Detected 558701 anomalies out of 6940237 rows in Batch 5
#
# 🔹 Processing Batch 6: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/preprocessed_batch_14.csv
# Epoch [1/1] Loss: 0.828676
# ✅ Model saved: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/autoencoder_progressive.pth
# ✅ Model saved: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/autoencoder_progressive.h5
# ✅ Train Accuracy for Batch 6: 0.9112
# ✅ Anomalies saved to /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/anomaly_results_batch_6.csv
# 🔔 Detected 616143 anomalies out of 6939868 rows in Batch 6
#
# 🔹 Processing Batch 7: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/preprocessed_batch_15.csv
# Epoch [1/1] Loss: 0.827468
# ✅ Model saved: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/autoencoder_progressive.pth
# ✅ Model saved: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/autoencoder_progressive.h5
# ✅ Train Accuracy for Batch 7: 0.9040
# ✅ Anomalies saved to /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/anomaly_results_batch_7.csv
# 🔔 Detected 666384 anomalies out of 6939793 rows in Batch 7
#
# 🔹 Processing Batch 8: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/preprocessed_batch_2.csv
# Epoch [1/1] Loss: 0.828221
# ✅ Model saved: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/autoencoder_progressive.pth
# ✅ Model saved: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/autoencoder_progressive.h5
# ✅ Train Accuracy for Batch 8: 0.9169
# ✅ Anomalies saved to /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/anomaly_results_batch_8.csv
# 🔔 Detected 577011 anomalies out of 6939679 rows in Batch 8
#
# 🔹 Processing Batch 9: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/preprocessed_batch_3.csv
# Epoch [1/1] Loss: 0.827613
# ✅ Model saved: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/autoencoder_progressive.pth
# ✅ Model saved: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/autoencoder_progressive.h5
# ✅ Train Accuracy for Batch 9: 0.9254
# ✅ Anomalies saved to /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/anomaly_results_batch_9.csv
# 🔔 Detected 517975 anomalies out of 6939683 rows in Batch 9
#
# 🔹 Processing Batch 10: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/preprocessed_batch_4.csv
# Epoch [1/1] Loss: 0.827302
# ✅ Model saved: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/autoencoder_progressive.pth
# ✅ Model saved: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/autoencoder_progressive.h5
# ✅ Train Accuracy for Batch 10: 0.9249
# ✅ Anomalies saved to /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/anomaly_results_batch_10.csv
# 🔔 Detected 521052 anomalies out of 6939741 rows in Batch 10
#
# 🔹 Processing Batch 11: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/preprocessed_batch_5.csv
# Epoch [1/1] Loss: 0.824541
# ✅ Model saved: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/autoencoder_progressive.pth
# ✅ Model saved: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/autoencoder_progressive.h5
# ✅ Train Accuracy for Batch 11: 0.9456
# ✅ Anomalies saved to /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/anomaly_results_batch_11.csv
# 🔔 Detected 377650 anomalies out of 6939788 rows in Batch 11
#
# 🔹 Processing Batch 12: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/preprocessed_batch_6.csv
# Epoch [1/1] Loss: 0.819403
# ✅ Model saved: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/autoencoder_progressive.pth
# ✅ Model saved: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/autoencoder_progressive.h5
# ✅ Train Accuracy for Batch 12: 0.9471
# ✅ Anomalies saved to /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/anomaly_results_batch_12.csv
# 🔔 Detected 366955 anomalies out of 6939982 rows in Batch 12
#
# 🔹 Processing Batch 13: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/preprocessed_batch_7.csv
# Epoch [1/1] Loss: 0.818137
# ✅ Model saved: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/autoencoder_progressive.pth
# ✅ Model saved: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/autoencoder_progressive.h5
# ✅ Train Accuracy for Batch 13: 0.9515
# ✅ Anomalies saved to /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/anomaly_results_batch_13.csv
# 🔔 Detected 336326 anomalies out of 6940248 rows in Batch 13
#
# 🔹 Processing Batch 14: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/preprocessed_batch_8.csv
# Epoch [1/1] Loss: 0.818409
# ✅ Model saved: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/autoencoder_progressive.pth
# ✅ Model saved: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/autoencoder_progressive.h5
# ✅ Train Accuracy for Batch 14: 0.9360
# ✅ Anomalies saved to /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/anomaly_results_batch_14.csv
# 🔔 Detected 444076 anomalies out of 6940233 rows in Batch 14
#
# 🔹 Processing Batch 15: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/preprocessed_batch_9.csv
# Epoch [1/1] Loss: 0.817760
# ✅ Model saved: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/autoencoder_progressive.pth
# ✅ Model saved: /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/autoencoder_progressive.h5
# ✅ Train Accuracy for Batch 15: 0.9376
# ✅ Anomalies saved to /home/smartdragon/Videos/SWAT/SWaT.A1 & A2_Dec 2015/Data/Results/anomaly_results_batch_15.csv
# 🔔 Detected 433233 anomalies out of 6940340 rows in Batch 15
#
# ✅ Batchwise Anomaly Detection Completed.
